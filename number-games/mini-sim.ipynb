# %%
import numpy as np
import random
import time

# %%
lotto = list(np.arange(1, 43, 1))

# %%
moje = [22, 20, 32, 40, 33]
# wylosowane = []
trojki = []
czworki = []
piatki = []
nic = []

# %%
losowania = 10_000
for k in range(losowania):
  lotto = list(np.arange(1, 43, 1))
  wylosowane = []

  for i in range(5):
    x = random.choice(lotto)
    wylosowane.append(x)
    lotto.remove(x)
    i =+ 1

  wynik = []

  for j in range(5):
    if (moje[j] in wylosowane) is True:
      wynik.append(1)
    else:
      wynik.append(0)
    j=+1

  if sum(wynik) == 3:
    trojki.append(1)
  elif sum(wynik) == 4:
    czworki.append(1)
  elif sum(wynik) == 5:
    piatki.append(1)
  else:
    nic.append(1)

  k=+1

# %%
sum(nic), sum(trojki), sum(czworki), sum(piatki)
# Out:
# (10923, 75, 2, 0)

# %%
# print('A oto wylosowane dziś liczby:')
# time.sleep(3)

for k in range(len(wylosowane)):
  print(wylosowane[k])
  time.sleep(2)
  k=+1
# Out:
# 32
# 30
# 11
# 13
# 38

# %%
wynik = []

for i in range(5):
  if (moje[i] in wylosowane) is True:
    wynik.append(1)
  else:
    wynik.append(0)
  
  i=+1

# %%
for i in range(5):
  print(moje[i])
  i=+1
# Out:
# 23
# 24
# 27
# 28
# 29

# %%
wynik[1] in wylosowane
# Out:
# False

# %%
sum(wynik)
# Out:
# 2
